# %%
import matplotlib.pyplot as plt
import numpy as np


fname = 'experimentdata.csv'
# the data file fname has x data (first column) and y data (second column) and
# the uncertianty in y (third column).
# Enter the name and units of each column here so that the plots are properly
# labeled. e.g. x_name = 'Time', x_units = 'ms', y_name = 'Voltage', y_units
# = 'V'.
x_name = 'Frequency'
x_units = 'Hz'
y_name = 'Vout/Vin'
y_units = 'no units'

titles = ("Temperature over time for rough rod", "Temperature over time for polished rod", "Temperature over time for lacquered rod")

colours = ["ro", "go", "bo"]

data = np.loadtxt(fname, delimiter=',', comments='#',
                 usecols=(0, 4, 5, 6))
# access the data columns and assign variables x,y  and  uncetainty in y y_sigma
x = data[:, 0]
for i in range(1,4):
    y = data[:, i]
    # y_sigma = data[:, ]
    plt.figure(1)
    plt.plot(x,y)
    plt.title(types[i-1])
    plt.xlabel("Time(s)")
    plt.ylabel("Temperature(K)")
    plt.show()

plt.figure(2)
plt.plot(x, data[:, 1], x, data[:, 2], x, data[:, 3])
# Out:
# [<matplotlib.lines.Line2D at 0x120b59060>,
#  <matplotlib.lines.Line2D at 0x120b590c0>,
#  <matplotlib.lines.Line2D at 0x120b58fd0>]
