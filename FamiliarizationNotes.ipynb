# %% [markdown]
# # Monday, Jan. 9, 2:00 PM

# %% [markdown]
# ## Experiment #1 - Week 1 - Familiarization Notes

# %% [markdown]
# ## Working with Cooling Mechanisms and Modelling

# %% [markdown]
# # Clarify Objective

# %% [markdown]
# We will be collecting data from the cooling process of the rods and will use numerical models to simulate the cooling process and compare these simulations to the empirical evidence.
#
# Temperature of air and aluminum cylinders will be represented by $T$ and will have units of Kelvin.
#
# Time will be represented by $t$ and will have units of seconds.
#
# Length of aluminum cylinders will be represented by $l$ and will have units of $mm$.
#
# Radius of aluminum cyclinders will be represented by $r$ and will have units of $mm$.
#
# Surface area of aluminum cylinders will be represented by $A$ and will have units of $mm^2$.
#
# Density of aluminum will be represented by $\rho$ and will have units of $\dfrac{kg}{mm^3}$.
#
# Volume of aluminum cylinders will be represented by $V$ and will have units of $mm^3$.
#
# Heat will be represented by $Q$ and will have units of $J$.
#
# Heat capacity of aluminum will be represented by $C$ and will have units of $\dfrac{J}{kg*K}$.
#
# Mass of aluminum cylinders will be represented by $M$ and will have units of $kg$.
#
# Emmisivity of materials will be represented by $e$ and will have no units.
#
# The Stefan-Boltzmann constant will be represented by $\sigma$ and will be equal to $5.670374419E-8 \dfrac{W}{m^2 * K^4}$
#
#
# My hypothesis is the aluminium rods will be heated up by the boiling water and will cool through radiation, convection with the air, and conduction through the wodden rod will not play a large role in the cooling process. I hypothesize the laquer rod will cool the fastest due to the high infrared emmesivity of the coating, the rough rod will cool the second fastest due to the higher surface area, and the polished rod will take the longest to cool.

# %% [markdown]
# # Explore Tools

# %% [markdown]
# __Tools:__
#
# Calipers (Range: 0mm - 155mm with uncertainty 0.05mm)
#
# Meter stick (Range: 0m - 1m with uncertainty 0.01m)
#
# Thermometer (Range: 253.15K - 383.15K with uncertainty 1K)
#
# Hot plate
#
# Lacquered, polished, and rough aluminum rods
#
# Pot of water
#
# __Noise sources in measurement:__
#
# Inconsistent air currents in room causing variation in convection.
#
# Incoming radiation adding thermal energy to the aluminum rods.
#
# __Other sources of uncertainty:__
#
# Parallax effect (read error).
#
# It is difficult to take the temperature reading at exactly the right time interval leading to an unvertainty of 1s in time measurements.
#
# __Systematic errors:__
#
# We have to touch and move the thermometers and rods influencing their temperature and therefore the temperature measurements.
#
# The aluminum cylinder in the middle is between 2 other aluminum cylinders which are also emitting heat through radiation and convection which may slightly heat this center aluminum cylinder and reduce the cooling rate relative to the aluminum cylinders on the sides.

# %% [markdown]
# # Relate Quantities

# %% [markdown]
# __Required equations:__
#
# Conduction equation: $\dfrac{dQ}{dt} = -kA \dfrac{dT}{dx}$
#
# Radiation equation: $\dfrac{dQ}{dt} = -A e \sigma T^4$
#
# Convection equation: $\dfrac{dQ}{dt} = -hA(T-T_0)$
#
# $h$ constant for a cylinder: $h = 1.32 \dfrac{J}{m^{7/4} s K^{5/4}}(\dfrac{T-T_0}{2r})^{1/4}$
#
# $V_{cylinder} = \pi r^2 L$
#
# $A_{cylinder} = 2 \pi r L$
#
# $\dfrac{dQ}{dt} = MC \dfrac{dT}{dt} = \rho VC \dfrac{dT}{dt}$
#
# __Required statistical tools:__
#
# Uncertainty propegation.
#
# $\sigma^2_F = \left(\dfrac{\partial F}{\partial x_1} \right)^2 \sigma_{x_1}^2 + \left(\dfrac{\partial F}{\partial x_2} \right)^2 \sigma_{x_2}^2 + ... + \left(\dfrac{\partial F}{\partial x_n}\right)^2 \sigma_{x_n}^2$
#
# T-score.
#
# $t' = \dfrac{|A-B|}{\sqrt{\sigma_A^2+\sigma_B^2}}$
#
# __Planned graphs__
#
# Measured temperature over time.
# Simulated temperature over time.
#
# __Uncertainty propegations:__

# %% [markdown]
# # Test and Try

# %% [markdown]
# __Temperature measurements over time__
#
# $T_0$ = 299K, ambient temp
#
# R = Rough, P = Polished, L = Lacquered
#
# All time measurements have $\sigma = 1s$ and all temperature measurements have $\sigma = 1K$
#
# t=0s
#
# R:358.15K,
# P:357.15K,
# L:356.15K
#
# t=120s
#
# R:354.15K,
# P:352.15K,
# L:351.15K
#
# t=180s
#
# R:352.15K,
# P:350.15K,
# L:348.65K
#
# t=240s
#
# R:350.15K,
# P:348.15K,
# L:346.95K
#
# t=300s
#
# R:348.15K,
# P:346.15K,
# L:344.15K
#
# t=360s
#
# R:345.15K,
# P:344.15K,
# L:340.15K
#
# t=420s
#
# R:343.15K,
# P:343.15K,
# L:338.15K
#
# t=480s
#
# R:342.15K,
# P:342.15K,
# L:337.15K
#
# t=540s
#
# R:340.15K,
# P:340.65K,
# L:335.15K
#
# t=600s
#
# R:338.15K,
# P:339.65K,
# L:333.15K
#
# t=660s
#
# R:336.65K,
# P:338.15K,
# L:331.15K
#
# t=720s
#
# R:335.15K,
# P:337.15K,
# L:329.65K
#
# t=780s
#
# R:333.65K,
# P:335.85K,
# L:328.15K
#
# t=840s
#
# R:332.15K,
# P:334.65K,
# L:326.65K
#
# t=900s
#
# R:330.65K,
# P:333.65K,
# L:325.15K
#
# t=960s
#
# R:329.15K,
# P:332.25K,
# L:323.65K
#
# t=1020s
#
# R:328.15K,
# P:331.15K,
# L:322.65K
#
# t=1080s
#
# R:326.95K,
# P:330.15K,
# L:321.15K
#
# t=1140s
#
# R:325.65K,
# P:329.15K,
# L:320.15K
#
# t=1200s
#
# R:324.65K,
# P:328.15K,
# L:319.15K

# %% [markdown]
# __Aluminum cylinders dimensions__
#
# 3 metal rods with a wooden handle (Polished, Lacquered, and Rough aluminum rods)
#
# Polished rod dimensions:
#
# r = 11mm +/- 0.05mm, l = 302mm +/- 1mm
#
# hole l = 81mm +/- 0.05mm, hole r = 3.5mm +/- 0.05mm
#
# V = 111,683mm^3 +/- 1,111mm^3
#
# A = 20,873mm^2 +/- 117mm^2
#
# Lacquered rod dimensions:
#
# r = 13mm +/- 0.05mm, l = 272mm +/- 1mm
#
# hole l = 77mm +/- 0.05mm, hole r = 3.45mm +/- 0.05mm
#
# V = 141,534mm^3 +/- 1,231mm^3
#
# A = 22,217mm^2 +/- 118mm^2
#
# Rough rod dimensions:
#
# r = 13mm +/- 0.05mm, l = 303mm +/- 1mm
#
# hole l = 79mm +/- 0.05mm, hole r = 3.45mm +/- 0.05mm
#
# V = 157,918mm^3 +/- 1,347mm^3
#
# A = 24,750mm^2 +/- 125mm^2 (likely larger due to rough surface)

# %% [markdown]
# __Relevant physical quantities__
#
# Density of aluminum: $\rho = 2.71E-6 \dfrac{kg}{mm^3}$ https://www.thyssenkrupp-materials.co.uk/density-of-aluminium.html
#
# Heat capacity of aluminum: $C = 897 \dfrac{J}{kg*K}$ https://www.sciencedirect.com/topics/engineering/specific-heat-capacity
#
# Emmisivity of lacquer: $e = 0.9$ https://www.design1st.com/Design-Resource-Library/engineering_data/ThermalEmissivityValues.pdf
#
# Emmisivity of polished aluminum: $e = 0.05$ https://www.design1st.com/Design-Resource-Library/engineering_data/ThermalEmissivityValues.pdf
#
# Emmisivity of rough aluminum: $e = 0.1$ https://www.design1st.com/Design-Resource-Library/engineering_data/ThermalEmissivityValues.pdf

# %%
import numpy as np
from scipy import integrate
import matplotlib.pyplot as plt

sigma = 5.670374419E-8

emmL = 0.9
emmP = 0.05
emmR = 0.1

rhoAl = 2.71E-6
hcAl = 897

volL = 141,534
volP = 111,683
volR = 157,918

saL = 22,217
saP = 20,873
saR = 24,750

radL = 13E-3
radP = 11E-3
radR = 13E-3

massL = rhoAl * volL
massP = rhoAl * volP
massR = rhoAl * volR
